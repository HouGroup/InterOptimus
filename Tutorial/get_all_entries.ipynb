# %%
from mp_api.client import MPRester
# Out:
# /opt/anaconda3/envs/3.12/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import pickle

# %%
from monty.serialization import dumpfn, loadfn

# %%
API_KEY = 'fFtrdShVJH4jwWHiId8v4cyGzV2oYnoG'
mpr = MPRester(API_KEY)
entries = mpr.get_entries('', additional_criteria = {"thermo_types": ["GGA_GGA+U", "R2SCAN"], 'is_stable':True})
# Out:
# /Users/jason/Downloads/pymatgen-master/src/pymatgen/core/composition.py:1399: UserWarning: No Pauling electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   return sorted(sym, key=lambda x: [float("inf") if math.isnan(e_neg := get_el_sp(x).X) else e_neg, x])
# /Users/jason/Downloads/pymatgen-master/src/pymatgen/core/composition.py:1399: UserWarning: No Pauling electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   return sorted(sym, key=lambda x: [float("inf") if math.isnan(e_neg := get_el_sp(x).X) else e_neg, x])
# /Users/jason/Downloads/pymatgen-master/src/pymatgen/core/composition.py:1399: UserWarning: No Pauling electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
# ...

# %%
dumpfn(entries, 'all_entries.jason.gz')
