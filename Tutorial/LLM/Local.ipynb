# %%
import sys

# %%
from InterOptimus.agents.llm_iomaker_job import print_config_help, LocalBuildConfig, build_iomaker_flow_from_prompt
print_config_help()
# Out:
# ...
# BuildConfig 使用说明（先实例化了解参数，再传 prompt）
#
# 【提交模式】
# - 本地提交：使用 LocalBuildConfig
# - 远程提交：使用 RemoteBuildConfig
#
# 【本地模式必填】
# - api_key, base_url
#
# 【远程模式必填】
# - api_key, base_url
# - mlip_resources, vasp_resources
# - mlip_worker, vasp_worker
# - remote_host, remote_identity_file, remote_workdir, remote_passphrase
# - remote_conda_env（只需填 conda 环境名，如 atomate2）
#
# 【常用可选参数】
# - mp_api_key: Materials Project API Key
# - film_cif / substrate_cif: 本地 CIF 路径
# - output_flow_json: 输出 JSON 文件名
# - vasp_relax_settings / vasp_static_settings: VASP 设置
# - do_mlip_gd: 是否做 MLIP 梯度下降
# - do_vasp_gd: 是否做 VASP GD
# - lowest_energy_pairs_settings: 筛选最佳 pairs 的参数（如 only_lowest_energy_each_plane）
# - ckpt_path: MLIP checkpoint 路径
#
# 【Prompt 关键词控制（更详细）】
# - 真空层：
#   - '无真空/不加真空/不要真空/without vacuum/no vacuum' → without_vacuum
#   - '双界面/double interface/double_interface' → without_vacuum（强制）
# - VASP：
#   - 包含“VASP/DFT/电子结构/静态/弛豫”等关键词 → do_vasp=True
#   - 本地模式下会强制 do_vasp=False（不跑 VASP）
# - 梯度下降：
# ...

# %%
import os
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 import os
# ----> 2 os.getcwd()
#
# FileNotFoundError: [Errno 2] No such file or directory

# %%
cfg = LocalBuildConfig(api_key = "sk-zk29a8909a9badfb2973536dfd5a1bf41c7696742c764c35", 
                           base_url = "https://api.zhizengzeng.com/v1/")

# %%
result = build_iomaker_flow_from_prompt("建立双界面模型，厚度为10，最大匹配面积不超过20，最大长度，角度应变不超过5%", cfg)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result = build_iomaker_flow_from_prompt("建立双界面模型，厚度为10，最大匹配面积不超过20，最大长度，角度应变不超过5%", cfg)
#
# File ~/Documents/GitHub/InterOptimus/InterOptimus/agents/llm_iomaker_job.py:1153, in build_iomaker_flow_from_prompt(user_prompt, cfg)
#    1148 # (No further normalization needed: preset is authoritative)
#    1149
#    1150
#    1151 # Load structures:
#    1152 effective_mp_key = cfg.mp_api_key or os.getenv("MP_API_KEY")
# -> 1153 film_conv, substrate_conv, meta = load_structures(
#    1154     cfg.film_cif,
#    1155     cfg.substrate_cif,
#    1156     mp_api_key=effective_mp_key,
#    1157     film_mp_id=film_mp_id if in_type == "mp_id" else None,
#    1158     substrate_mp_id=substrate_mp_id if in_type == "mp_id" else None,
#    1159 )
#    1161 # Structure info for report (formula + spacegroup)
# ...
