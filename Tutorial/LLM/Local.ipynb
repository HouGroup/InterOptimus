# %%
from InterOptimus.agents.llm_iomaker_job import print_config_help, LocalBuildConfig, build_iomaker_flow_from_prompt
print_config_help()
# Out:
# /opt/anaconda3/envs/3.12/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# ...
# BuildConfig 使用说明（先实例化了解参数，再传 prompt）
#
# 【提交模式】
# - 本地提交：使用 LocalBuildConfig
# - 远程提交：使用 RemoteBuildConfig
#
# 【本地模式必填】
# - api_key, base_url
#
# 【远程模式必填】
# - api_key, base_url
# - mlip_resources, vasp_resources
# - mlip_worker, vasp_worker
# - remote_host, remote_identity_file, remote_workdir, remote_passphrase
# - remote_conda_env（只需填 conda 环境名，如 atomate2）
#
# 【常用可选参数】
# - mp_api_key: Materials Project API Key
# - film_cif / substrate_cif: 本地 CIF 路径
# - output_flow_json: 输出 JSON 文件名
# - vasp_relax_settings / vasp_static_settings: VASP 设置
# - do_mlip_gd: 是否做 MLIP 梯度下降
# - do_vasp_gd: 是否做 VASP GD
# - lowest_energy_pairs_settings: 筛选最佳 pairs 的参数（如 only_lowest_energy_each_plane）
# - ckpt_path: MLIP checkpoint 路径
#
# 【Prompt 关键词控制（更详细）】
# - 真空层：
# ...

# %%
cfg = LocalBuildConfig(api_key = "", 
                           base_url = "")

# %%
result = build_iomaker_flow_from_prompt("建立单界面模型，厚度为10，最大匹配面积不超过20，最大长度，角度应变不超过5%，不运行", 
                                        cfg)
# Out:
# ...
# ✅ InterOptimus IOMaker job generated
# 📄 Flow JSON: /Users/jason/Documents/GitHub/InterOptimus/Tutorial/LLM/IO_Li2S-Ni3S2_m-vac_v0_mlip-orb_20260122-224433_4cebf1e8/io_flow.json
# 📦 Structures source: local_cif
# 🧱 film.cif: /Users/jason/Documents/GitHub/InterOptimus/Tutorial/LLM/film.cif
# 🧱 substrate.cif: /Users/jason/Documents/GitHub/InterOptimus/Tutorial/LLM/substrate.cif
#
# ⚙️  Jobflow configuration:
#    MLIP worker: std_worker
#    MLIP resources: ❌ Not set (using defaults)
#
# 🔧 Parameter settings (LLM output normalized):
# {
#   "name": "IO_Li2S-Ni3S2_m-vac_v0_mlip-orb_20260122-224433_4cebf1e8",
#   "mode": "with_vacuum",
#   "inputs": {
#     "type": "local_cif",
#     "film_cif": "film.cif",
#     "substrate_cif": "substrate.cif"
#   },
#   "lattice_matching_settings": {
#     "max_area": 20.0,
#     "max_length_tol": 0.05,
#     "max_angle_tol": 0.05,
#     "film_max_miller": 3,
#     "substrate_max_miller": 3,
#     "film_millers": null,
#     "substrate_millers": null
# ...
