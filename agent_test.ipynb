# %%
from InterOptimus.agents.mp_interface_agent import MPInterfaceAgent

API_SECRET_KEY = "sk-zk29a8909a9badfb2973536dfd5a1bf41c7696742c764c35";
BASE_URL = "https://api.zhizengzeng.com/v1/"

agent = MPInterfaceAgent(mp_api_key="LBPWGcTye2eanNBb7dtmTp2deXR4aF9E",
                        api_key = API_SECRET_KEY,
                        base_url= BASE_URL)

# 自动下载并生成界面
result = agent.generate_interface_from_text_mp(
    "Create silicon on aluminum oxide interface",
    output_dir="mp_interfaces"
)

if result['success']:
    mp_info = result['mp_info']
    print(f"MP IDs used: {mp_info['mp_ids_used']}")
    print(f"Structures downloaded: {mp_info['structures_downloaded']}")
# Out:
# /opt/anaconda3/envs/3.12/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from InterOptimus.agents.mp_interface_agent import MPInterfaceAgent
#       3 API_SECRET_KEY = "sk-zk29a8909a9badfb2973536dfd5a1bf41c7696742c764c35";
#       4 BASE_URL = "https://api.zhizengzeng.com/v1/"
#
# File ~/Documents/GitHub/InterOptimus/InterOptimus/agents/mp_interface_agent.py:24
#      21     HAS_MP_API = False
#      22     print("⚠️  Materials Project API不可用，请安装pymatgen with MP support")
# ---> 24 from llm_interface_agent import LLMInterfaceAgent, LLMInterfaceRequest
#      27 @dataclass
#      28 class MPInterfaceRequest(LLMInterfaceRequest):
# ...
